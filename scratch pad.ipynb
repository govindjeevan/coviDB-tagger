# %%
import requests
from bs4 import BeautifulSoup
from joblib import Parallel, delayed
import yaml
import multiprocessing
from tqdm import tqdm
from datetime import datetime
import urllib.parse
import utils

# %%
x = "https://www.nejm.org/doi/full/10.1056/NEJMp2106137"

# %%
x.split("/")[3]
# Out:
# 'doi'

# %%
mappings = utils.load_mappings()

# %%
c = utils.get_category(x)

# %%
 a= find_tag(mappings, utils.get_host(x), c)
# Out:
# medical-articles perspective

# %%
a
# Out:
# 'non-technical'

# %%
from newspaper import Article
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8" />
#         <meta name="norton-safeweb-site-verification" content="24usqpep0ejc5w6hod3dulxwciwp0djs6c6ufp96av3t4whuxovj72wfkdjxu82yacb7430qjm8adbd5ezlt4592dq4zrvadcn9j9n-0btgdzpiojfzno16-fnsnu7xd" />
#
#
#
#         <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" />
#         <meta name="author" content="Katelyn Jetelina" />
#         <meta property="og:url" content="https://yourlocalepidemiologist.substack.com/p/j-and-j-and-delta-update" />
#         <link rel="canonical" href="https://yourlocalepidemiologist.substack.com/p/j-and-j-and-delta-update" />
#
#
#
#
#
#
#
#                 <link rel="shortcut icon" href="https://cdn.substack.com/icons/substack/favicon.ico">
#
#
#
#                 <link rel="icon" type="image/png" sizes="16x16" href="https://cdn.substack.com/icons/substack/favicon-16x16.png">
#
#
#
# ...

# %%
print(article.text)
# Out:
# Last night, Johnson and Johnson announced that their one dose regimen works against Delta. I wanted to see the actual science before updating you all. Here it is.
#
# Important context. There are two ways to measure how well a vaccine works: Efficacy and immunogenicity. Immunogenicity is a more complicated metric that measures the type of immune responses that the vaccine generates and their magnitude over time (i.e. neutralizing antibodies). This study looked at immunogenicity.
#
# Scientists took blood samples from 8 of their clinical trial participants. Then, in petri dishes, they infected the blood with Delta (and other variants). Neutralizing antibodies are good, so they watched how many decreased when introduced to Delta (which is labeled B.1.617.2 in the graph below). They found a 1.6-fold decrease in neutralizing antibodies.
#
# What does this mean in terms of efficacy?
#
# ...

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
article.nlp()

# %%
article.keywords
# Out:
# ['responses',
#  'months',
#  'efficacy',
#  'work',
#  'jj',
#  'update',
#  'neutralizing',
#  'delta',
#  'vaccine',
#  'works',
#  'antibodies']

# %%
article.summary
# Out:
# 'There are two ways to measure how well a vaccine works: Efficacy and immunogenicity.\nneutralizing antibodies).\nNeutralizing antibodies are good, so they watched how many decreased when introduced to Delta (which is labeled B.1.617.2 in the graph below).\nIn the same update, J&J said their vaccine continues to work over time, with strong responses for up to 8 months.\nSo, yes, the J&J vaccine still works, to some degree, against Delta.'

# %%
import csv
labels = []
with open('labels.csv', 'r') as fd:
    reader = csv.reader(fd)
    for row in reader:
        labels.append(row[0])

# %%
import utils
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
titles = [['doses',
  'ordered',
  'vaccine',
  'moderna',
  'verified',
  'million',
  'receive',
  'submitted',
  'delivery',
  'quarter'],
 ['agreement',
  'phase',
  'supply',
  'australia',
  'mrna',
  'booster',
  'study',
  'announces',
  'covid19',
  'moderna',
  'forwardlooking',
  'statements',
  '25',
  'doses',
  'million',
  'vaccine'],
 ['websites',
  'external',
  'visit',
  '000112760221016223',
  'websitescontinue',
  'statements',
  'privacy',
  'responsibility',
  'moderna',
  'policy',
  'website'],
 ['website',
  'moderna',
  'websitescontinue',
  'policy',
  'visit',
  'responsibility',
  '000112760221016817',
  'websites',
  'statements',
  'external',
  'privacy'],
 ['external',
  'policy',
  '000112760221016798',
  'websitescontinue',
  'moderna',
  'visit',
  'responsibility',
  'websites',
  'website',
  'statements',
  'privacy'],
 [],
 ['international',
  'poland',
  'forwardlooking',
  'mrna',
  'services',
  'moderna',
  'commercial',
  'statements',
  'center',
  'business',
  'regulatory',
  'global',
  'warsaw',
  'hub',
  'modernas',
  'establish'],
 None,
 ['japans',
  'labour',
  'health',
  'mrna',
  'welfare',
  'japan',
  'forwardlooking',
  'study',
  'vaccine',
  'statements',
  'commercial',
  'approves',
  'mhlw',
  'covid19',
  'ministry',
  'moderna',
  'modernas'],
 ['website',
  'responsibility',
  '000112760221017202',
  'visit',
  'external',
  'privacy',
  'websites',
  'moderna',
  'statements',
  'websitescontinue',
  'policy'],
 ['collaboration',
  'vaccine',
  'mrna',
  'vaccines',
  'south',
  'moderna',
  'modernas',
  'manufacturing',
  'explore',
  'korea',
  'statements',
  'covid19'],
 ['samsung',
  'agreement',
  'forwardlooking',
  'mrna',
  'vaccine',
  'biologics',
  'statements',
  'manufacturing',
  'covid19',
  'moderna',
  'fillfinish',
  'modernas',
  'announce'],
 ['mrna',
  'drug',
  'modernas',
  'covid19',
  'moderna',
  'forwardlooking',
  'statements',
  'mfds',
  'food',
  'korea',
  'safety',
  'manufacturing',
  'ministry',
  'vaccine',
  'south'],
 ['forwardlooking',
  'aldevron',
  'mrna',
  'covid19',
  'vaccines',
  'moderna',
  'pipeline',
  'manufacturing',
  'statements',
  'announce',
  'programs',
  'partnership',
  'expanded',
  'modernas',
  'vaccine',
  'therapeutic'],
 ['2020',
  'primary',
  'mrna1273',
  'vaccine',
  'plans',
  'phase',
  'regulators',
  'mrna',
  'moderna',
  'teencove',
  'meets',
  'forwardlooking',
  'submit',
  'statements',
  'covid19',
  'endpoint',
  'study'],
 [],
 ['annual',
  'innovative',
  'stem',
  'submitted',
  'platform',
  'fourth',
  'science',
  'vaccine',
  'highlights',
  'selection',
  'sarscov2',
  'vaccines',
  'variants',
  'moderna',
  'research',
  'verified',
  'technology',
  'lipid',
  'nanoparticle',
  'day'],
 ['role',
  'pacific',
  'questions',
  'islander',
  'moderna',
  'science',
  'mrna',
  'heritage',
  'huijuan',
  'asian',
  'inclusion',
  'li',
  'answers'],
 [],
 ['website',
  'responsibility',
  'visit',
  'external',
  'privacy',
  'websites',
  'moderna',
  'statements',
  'websitescontinue',
  'policy'],
 ['external',
  'policy',
  'visit',
  'websitescontinue',
  'moderna',
  '000112760221018003',
  'statements',
  'responsibility',
  'websites',
  'website',
  'privacy'],
 [],
 ['website',
  'annual',
  'moderna',
  'privacy',
  'visit',
  'goldman',
  'healthcare',
  'conference',
  'external',
  'websitescontinue',
  'policy',
  'websites',
  'statements',
  'sachs',
  'responsibility',
  '42nd'],
 ['moderna',
  'phase',
  'study',
  'forwardlooking',
  'bla',
  'initiation',
  'rolling',
  'submission',
  'license',
  'covid19',
  '2020',
  'biologics',
  'statements',
  'mrna',
  'vaccine',
  'fda'],
 ['forwardlooking',
  'thermo',
  'mrna',
  'announces',
  'moderna',
  'manufacturing',
  'vaccines',
  'statements',
  'fillfinish',
  'regulatory',
  'fisher',
  'modernas',
  'vaccine',
  'scientific',
  'covid19'],
 ['lonza',
  'moderna',
  'phase',
  'netherlands',
  'announces',
  'forwardlooking',
  'substance',
  'drug',
  'booster',
  'covid19',
  'statements',
  'mrna',
  'agreement',
  'vaccine',
  'production',
  'manufacturing'],
 ['unicef',
  'supply',
  'vaccine',
  'facility',
  'phase',
  'announce',
  'mrna',
  'covax',
  'modernas',
  'moderna',
  'term',
  'long',
  'forwardlooking',
  'statements',
  'covid19',
  'behalf',
  'study'],
 ['emergency',
  'moderna',
  'phase',
  'republic',
  'announces',
  'study',
  'covid19',
  'supply',
  'mrna',
  'modernas',
  'agreement',
  'vaccine',
  'botswana'],
 ['websites',
  'external',
  'visit',
  'websitescontinue',
  'statements',
  'privacy',
  'responsibility',
  'moderna',
  'policy',
  'website'],
 ['approval',
  'moderna',
  'mrna1273',
  'safety',
  'marketing',
  'adolescents',
  'emergency',
  'files',
  'union',
  'european',
  'study',
  'vaccine',
  'conditional',
  'phase',
  'covid19',
  'authorization'],
 ['eastern',
  'partner',
  'israel',
  'commercial',
  'europe',
  'vaccine',
  'statements',
  'mrna',
  'modernas',
  'moderna',
  'regulatory',
  'medison',
  'forwardlooking',
  'pharma',
  'covid19'],
 [],
 [],
 ['robust',
  'mrna',
  'moderna',
  'science',
  'secreted',
  'rna',
  'technology',
  'transformative',
  'spectrum',
  'newsroom',
  'therapeutic',
  'medicines'],
 ['vacuna',
  'preguntas',
  'frecuentes',
  'sobre',
  'eua',
  'mes',
  'moderna',
  'en',
  'una',
  'contra',
  'la',
  'covid19',
  'serie',
  'dosis'],
 ['study',
  'moderna',
  'states',
  'dose',
  'safety',
  'mrna1273',
  'united',
  'adolescents',
  'files',
  'emergency',
  'vaccine',
  'phase',
  'covid19',
  'authorization'],
 ['website',
  'moderna',
  'websitescontinue',
  'policy',
  'visit',
  'responsibility',
  'websites',
  'statements',
  'external',
  '000112760221019511',
  'privacy'],
 ['partner',
  'commercialize',
  'vaccine',
  'tabuk',
  'mrna',
  'modernas',
  'moderna',
  'pharmaceuticals',
  'arabia',
  'statements',
  'covid19',
  'saudi'],
 [],
 ['risks',
  'forwardlooking',
  'reports',
  'covid19',
  'moderna',
  'uncertainties',
  'myocarditis',
  'statements',
  'pericarditis',
  'vaccine',
  'statement'],
 ['printed',
  'questions',
  'toaccounts',
  'payment',
  'standard',
  'supplier',
  'engagement',
  'term',
  'invoice',
  'regarding',
  'purchase',
  'submission'],
 ['external',
  'policy',
  'visit',
  'websitescontinue',
  'moderna',
  'statements',
  'responsibility',
  'websites',
  'website',
  '000112760221019515',
  'privacy'],
 ['website',
  'responsibility',
  '000112760221019713',
  'visit',
  'external',
  'privacy',
  'websites',
  'moderna',
  'statements',
  'websitescontinue',
  'policy'],
 ['moderna',
  'provide',
  'information',
  'eua',
  'medical',
  'vaccine',
  'emergency',
  'intended',
  'covid19',
  'providers'],
 ['officer',
  'join',
  'forwardlooking',
  'mrna',
  'chief',
  'moderna',
  'science',
  'paul',
  'statements',
  'company',
  'modernas',
  'dr',
  'medical',
  'burton'],
 ['adolescents',
  'authorization',
  'mrna1273',
  'vaccine',
  'phase',
  'mrna',
  'submits',
  'moderna',
  'study',
  'safety',
  'dose',
  'application',
  'covid19',
  'switzerland'],
 ['website',
  'moderna',
  'privacy',
  'visit',
  'external',
  'websitescontinue',
  'policy',
  'websites',
  'statements',
  'responsibility',
  '000112760221019715'],
 [],
 ['distribute',
  'mrna',
  'magenta',
  'variant',
  'moderna',
  'emirates',
  'partner',
  'united',
  'booster',
  'modernas',
  'study',
  'vaccine',
  'phase',
  'covid19',
  'updated']]

# %%
len(titles)
# Out:
# 49

# %%
labels = utils.read_label_list()

# %%
titles
# Out:
# [['doses',
#   'ordered',
#   'vaccine',
#   'moderna',
#   'verified',
#   'million',
#   'receive',
#   'submitted',
#   'delivery',
#   'quarter'],
#  ['agreement',
#   'phase',
#   'supply',
#   'australia',
#   'mrna',
#   'booster',
#   'study',
#   'announces',
#   'covid19',
#   'moderna',
#   'forwardlooking',
#   'statements',
#   '25',
#   'doses',
#   'million',
#   'vaccine'],
#  ['websites',
#   'external',
#   'visit',
#   '000112760221016223',
#   'websitescontinue',
#   'statements',
#   'privacy',
#   'responsibility',
#   'moderna',
#   'policy',
#   'website'],
#  ['website',
#   'moderna',
#   'websitescontinue',
#   'policy',
#   'visit',
#   'responsibility',
#   '000112760221016817',
#   'websites',
#   'statements',
#   'external',
#   'privacy'],
#  ['external',
#   'policy',
#   '000112760221016798',
#   'websitescontinue',
#   'moderna',
#   'visit',
#   'responsibility',
#   'websites',
#   'website',
#   'statements',
#   'privacy'],
#  [],
# ...

# %%
utils.closest_label(titles[0], labels, 1)
# Out:
# []

# %%
titles[0]
# Out:
# ['doses',
#  'ordered',
#  'vaccine',
#  'moderna',
#  'verified',
#  'million',
#  'receive',
#  'submitted',
#  'delivery',
#  'quarter']

# %%
import difflib

# %%
for x in titles[0]:
    print(x, difflib.get_close_matches(x, labels, 2, 0.8))
# Out:
# doses []
# ordered []
# vaccine ['Vaccine']
# moderna []
# verified []
# million []
# receive []
# submitted []
# delivery []
# quarter []

# %%
a = utils.closest_label_parallel(titles)
# Out:
# 100%|██████████| 49/49 [00:00<00:00, 3165.12it/s]

# %%
a
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  None,
#  [],
#  None,
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  None,
#  [],
#  [],
#  None,
#  [],
#  [],
#  None,
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  None,
#  None,
#  [],
#  [],
#  [],
#  [],
#  [],
#  None,
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  None,
#  []]
