# %%
import requests
from bs4 import BeautifulSoup
from joblib import Parallel, delayed
import yaml
import multiprocessing
from tqdm import tqdm
from datetime import datetime
import urllib.parse

# %%
x = "https://investors.modernatx.com/news-releases/news-release-details/moderna-and-medison-pharma-partner-commercialize-modernas-covid"

# %%
x.split("/")[4]
# Out:
# 'news-release-details'
